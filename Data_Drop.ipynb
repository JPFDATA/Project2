# %%
import pandas as pd

# %%
import numpy as np

# %%
df = {'A':[1, 2, np.nan], 'B':[3, np.nan, np.nan]}
df = pd.DataFrame(df)

# %%
df
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN

# %%
df.isnull()
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True   True

# %%
df.isnull().sum()
# Out:
# A    1
# B    2
# dtype: int64

# %% [markdown]
# df.dropna() method drops all rows with na values
# CHECK BELOW

# %%
df = {'A':[1, 2, np.nan], 'B':[3, np.nan, np.nan]}
df = pd.DataFrame(df)
print(df)
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN

# %% [markdown]
# df.dropna(axis=1)
# when this method is applied columns with any null values should be dropped.

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %% [markdown]
# df.dropna(thresh=2) sets a threshold that drops rows containing less than 2 non-null values

# %%
df.dropna(thresh=2)
# Out:
#      A    B
# 0  1.0  3.0

# %%
df
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN

# %% [markdown]
# df.dropna() method drops the entire row (and any row) contaning null value
# BELOW: THIS SET CONSISTS OF 2 COLUMNS & 3 ROWS, WHEN df.dropna() IS APPLIED THE ONLY ROW THAT REMAINS IS ROW '0' BECAUSE THAT ROW CONTAINS ZERO NULL VALUES

# %%
df.dropna()
# Out:
#      A    B
# 0  1.0  3.0

# %%
 df.dropna(subset=['B'])
# Out:
#      A    B
# 0  1.0  3.0

# %%
data = {'A': [1, 2, np.nan, 4, 5], 'B': [3, np.nan, np.nan, 6, 7]}
df = pd.DataFrame(data)
df
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN
# 3  4.0  6.0
# 4  5.0  7.0

# %%
df['B'].dropna(inplace=False)
# Out:
# 0    3.0
# 3    6.0
# 4    7.0
# Name: B, dtype: float64

# %%
df.isnull()
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True   True
# 3  False  False
# 4  False  False
